# %%
pip install statsmodels

# %%
pip install scikit-learn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Regression Using StatsModel

# %%
duncan_prestige = sm.datasets.get_rdataset("Duncan", "carData")

# %%
Y = duncan_prestige.data['income']

# %%
X = duncan_prestige.data['education']

# %%
X1 = sm.add_constant(X)

# %%
X1
# Out:
#                     const  education
# rownames
# accountant            1.0         86
# pilot                 1.0         76
# architect             1.0         92
# author                1.0         90
# chemist               1.0         86
# minister              1.0         84
# professor             1.0         93
# dentist               1.0        100
# reporter              1.0         87
# engineer              1.0         86
# undertaker            1.0         74
# lawyer                1.0         98
# physician             1.0         97
# welfare.worker        1.0         84
# teacher               1.0         91
# conductor             1.0         34
# contractor            1.0         45
# factory.owner         1.0         56
# store.manager         1.0         44
# banker                1.0         82
# bookkeeper            1.0         72
# mail.carrier          1.0         55
# insurance.agent       1.0         71
# store.clerk           1.0         50
# carpenter             1.0         23
# electrician           1.0         39
# RR.engineer           1.0         28
# machinist             1.0         32
# auto.repairman        1.0         22
# plumber               1.0         25
# gas.stn.attendant     1.0         29
# coal.miner            1.0          7
# streetcar.motorman    1.0         26
# taxi.driver           1.0         19
# truck.driver          1.0         15
# machine.operator      1.0         20
# barber                1.0         26
# bartender             1.0         28
# shoe.shiner           1.0         17
# cook                  1.0         22
# soda.clerk            1.0         30
# watchman              1.0         25
# janitor               1.0         20
# policeman             1.0         47
# waiter                1.0         32

# %%
model = sm.OLS(Y,X1)

# %%
results = model.fit()

# %%
results.params
# Out:
# const        10.603498
# education     0.594859
# dtype: float64

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 income   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     47.51
# Date:                Wed, 05 Jun 2024   Prob (F-statistic):           1.84e-08
# Time:                        10:10:05   Log-Likelihood:                -190.42
# No. Observations:                  45   AIC:                             384.8
# Df Residuals:                      43   BIC:                             388.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.6035      5.198      2.040      0.048       0.120      21.087
# education      0.5949      0.086      6.893      0.000       0.421       0.769
# ==============================================================================
# Omnibus:                        9.841   Durbin-Watson:                   1.736
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.609
# Skew:                           0.776   Prob(JB):                      0.00497
# Kurtosis:                       4.802   Cond. No.                         123.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fits = results.fittedvalues.values

# %%
fits
# Out:
# array([61.76141016, 55.81281576, 65.3305668 , 64.14084792, 61.76141016,
#        60.57169128, 65.92542624, 70.08944232, 62.3562696 , 61.76141016,
#        54.62309688, 68.89972344, 68.304864  , 60.57169128, 64.73570736,
#        30.82871928, 37.37217312, 43.91562696, 36.77731368, 59.3819724 ,
#        53.433378  , 43.32076752, 52.83851856, 40.34647032, 24.28526544,
#        33.80301648, 27.25956264, 29.6390004 , 23.690406  , 25.47498432,
#        27.85442208, 14.7675144 , 26.06984376, 21.90582768, 19.52638992,
#        22.50068712, 26.06984376, 27.25956264, 20.7161088 , 23.690406  ,
#        28.44928152, 25.47498432, 22.50068712, 38.561892  , 29.6390004 ])

# %%
pd.DataFrame(fits, Y)
# Out:
#                 0
# income
# 62      61.761410
# 72      55.812816
# 75      65.330567
# 55      64.140848
# 64      61.761410
# 21      60.571691
# 64      65.925426
# 80      70.089442
# 67      62.356270
# 72      61.761410
# 42      54.623097
# 76      68.899723
# 76      68.304864
# 41      60.571691
# 48      64.735707
# 76      30.828719
# 53      37.372173
# 60      43.915627
# 42      36.777314
# 78      59.381972
# 29      53.433378
# 48      43.320768
# 55      52.838519
# 29      40.346470
# 21      24.285265
# 47      33.803016
# 81      27.259563
# 36      29.639000
# 22      23.690406
# 44      25.474984
# 15      27.854422
# 7       14.767514
# 42      26.069844
# 9       21.905828
# 21      19.526390
# 21      22.500687
# 16      26.069844
# 16      27.259563
# 9       20.716109
# 14      23.690406
# 12      28.449282
# 17      25.474984
# 7       22.500687
# 34      38.561892
# 8       29.639000

# %%
sns.lineplot(Y, color = 'b')
sns.lineplot(fits, color = 'r')
# Out:
# <Axes: xlabel='rownames', ylabel='income'>

# %% [markdown]
# # Regression Using Sklearn

# %%
reg = LinearRegression() # define model

# %%
x = np.array(X)
y = np.array(Y)

# %%
x = x.reshape(-1,1)

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
print(reg.score(x,y)) # nilai R square
# Out:
# 0.5249181546907553

# %%
print("Intercept: ", reg.intercept_)
print("Coeficient: ", reg.coef_)
# Out:
# Intercept:  10.603498317842273
# Coeficient:  [0.59485944]

# %%
reg.fit
# Out:
# <bound method LinearRegression.fit of LinearRegression()>
